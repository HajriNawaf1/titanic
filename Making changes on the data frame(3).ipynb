# %%
import pandas as pd

# %%
! ls
# Out:
# Making changes on the data frame.ipynb python course presention.pptx
# Read and investigate the data.ipynb    titanic.csv
# Untitled.ipynb

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  21.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  37.0
# 2                             Heikkinen, Miss. Laina  female  25.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  34.0
# 4                           Allen, Mr. William Henry    male  34.0
#
#              Ticket     Fare Cabin
# 0         A/5 21171   7.2500   NaN
# 1          PC 17599  71.2833   C85
# 2  STON/O2. 3101282   7.9250   NaN
# 3            113803  53.1000  C123
# 4            373450   8.0500   NaN

# %%
df.shape
# Out:
# (891, 9)

# %% [markdown]
# ######  How I can change the value of string columns  ?

# %%
df['nationality'] = 'indian'

# %% [markdown]
# ###### How I can change the value of int columns  ?

# %%
df.Age = df.Age - 1

# %% [markdown]
# ###### how I can add new coulmns

# %%
df['nationality'] = 'Saudi'

# %% [markdown]
# ###### how I can drop the columns

# %%
del df['nationality']

# %% [markdown]
# ###### how I can drop duplicated of the column

# %%
df.drop_duplicates(subset=['Age'], keep='last' , inplace=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 33            34         0       2                     Wheadon, Mr. Edward H
# 111          112         0       3                      Zabour, Miss. Hileni
# 116          117         0       3                      Connors, Mr. Patrick
# 123          124         1       2                       Webber, Miss. Susan
# 125          126         1       3              Nicola-Yarred, Master. Elias
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age      Ticket     Fare Cabin
# ...

# %% [markdown]
# ###### how I can excelude columns of the data frame

# %%
df
# Out:
#                                                   Name            Ticket  \
# 0                              Braund, Mr. Owen Harris         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                               Heikkinen, Miss. Laina  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                             Allen, Mr. William Henry            373450
# ..                                                 ...               ...
# 886                              Montvila, Rev. Juozas            211536
# 887                       Graham, Miss. Margaret Edith            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"        W./C. 6607
# 889                              Behr, Mr. Karl Howell            111369
# 890                                Dooley, Mr. Patrick            370376
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ...

# %%
df_new= df[['Name','Ticket' , 'Fare']]

# %%
df_new
# Out:
#                                                   Name            Ticket  \
# 0                              Braund, Mr. Owen Harris         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                               Heikkinen, Miss. Laina  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                             Allen, Mr. William Henry            373450
# ..                                                 ...               ...
# 886                              Montvila, Rev. Juozas            211536
# 887                       Graham, Miss. Margaret Edith            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"        W./C. 6607
# 889                              Behr, Mr. Karl Howell            111369
# 890                                Dooley, Mr. Patrick            370376
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ...
