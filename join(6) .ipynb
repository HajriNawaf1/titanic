# %%
join :

# %%
import pandas as pd

# %%
! ls
# Out:
# 02-Retrieve data based on a condition - Copy.ipynb
# 04-Data analysis process example Patients - Copy.ipynb
# Calls.xlsx
# Customers.xlsx
# Making changes on the data frame(3).ipynb
# Read and investigate the data(1).ipynb
# aggregating using GroupBy and save file(5).ipynb
# join(6) .ipynb
# titanic.csv
# weather_by_cities.csv

# %%
Calls = pd.read_excel('Calls.xlsx')
Customers = pd.read_excel('Customers.xlsx')

# %%
Calls.head(100)
# Out:
#                Name     Products Talked About                   Notes  \
# 0   John F. Kennedy                     Phone            Did not care
# 1   John F. Kennedy          Notepad, Rolodex                     NaN
# 2   John F. Kennedy              IBM Computer   Too busy with Marilyn
# 3           Jack Ma             Phone, Laptop                 Neutral
# 4           Jack Ma               Apple Watch           Super excited
# 5     Nikolas Tesla                 AC cables      Needs by next week
# 6   Albert Einstein  Resistors, Circuit Board                     NaN
# 7   Albert Einstein   Notebook, Pencil, Chalk                     NaN
# 8       Gareth Bale                      Xbox   Excited and satisfied
# 9     Shahrukh Khan                      Xbox           Super psyched
# 10  Barbara Walters                Microphone  Nuetral on the product
# 11      Brett Favre                   Nothing                     NaN
# ...

# %%
Customers.head(100)
# Out:
#               Name                Address         City        State  \
# 0  John F. Kennedy       677 Timpany Blvd           DC           DC
# 1          Jack Ma         337 Russell St           NY           NY
# 2  Natalie Portman    295 Plymouth Street           LA           CA
# 3    Javier Bardem     1775 Washington St  Los Angeles   California
# 4    Nikolas Tesla  280 Washington Street     New York     New York
# 5  Albert Einstein          20 Soojian Dr    Princeton           NJ
# 6    Romelo Lukaku  301 Massachusetts Ave     Brussels          NaN
# 7      Gareth Bale         506 State Road       London          NaN
# 8    Shahrukh Khan        742 Main Street       Mumbai  Maharashtra
# 9  Barbara Walters             72 Main St        Miami           FL
#
#                    Email
# 0             jfk@us.gov
# 1     jackma@alibaba.com
# 2    natport@vendetta.eu
# 3     j.bardem@spain.org
# 4      tesla@awesome.com
# 5  einstein@inventor.com
# 6     lukaku@belgium.gov
# ...

# %%
dfCustomers = Calls.merge(Customers , how="left" , on="Name")

# %%
dfCustomers
# Out:
#                Name     Products Talked About                   Notes  \
# 0   John F. Kennedy                     Phone            Did not care
# 1   John F. Kennedy          Notepad, Rolodex                     NaN
# 2   John F. Kennedy              IBM Computer   Too busy with Marilyn
# 3           Jack Ma             Phone, Laptop                 Neutral
# 4           Jack Ma               Apple Watch           Super excited
# 5     Nikolas Tesla                 AC cables      Needs by next week
# 6   Albert Einstein  Resistors, Circuit Board                     NaN
# 7   Albert Einstein   Notebook, Pencil, Chalk                     NaN
# 8       Gareth Bale                      Xbox   Excited and satisfied
# 9     Shahrukh Khan                      Xbox           Super psyched
# 10  Barbara Walters                Microphone  Nuetral on the product
# 11      Brett Favre                   Nothing                     NaN
# ...

# %%
dfCustomers_left = Calls.merge(Customers , how="left" , on="Name")

# %%
dfCustomers_left
# Out:
#                Name                Address       City        State  \
# 0   John F. Kennedy       677 Timpany Blvd         DC           DC
# 1   John F. Kennedy       677 Timpany Blvd         DC           DC
# 2   John F. Kennedy       677 Timpany Blvd         DC           DC
# 3           Jack Ma         337 Russell St         NY           NY
# 4           Jack Ma         337 Russell St         NY           NY
# 5     Nikolas Tesla  280 Washington Street   New York     New York
# 6   Albert Einstein          20 Soojian Dr  Princeton           NJ
# 7   Albert Einstein          20 Soojian Dr  Princeton           NJ
# 8       Gareth Bale         506 State Road     London          NaN
# 9     Shahrukh Khan        742 Main Street     Mumbai  Maharashtra
# 10  Barbara Walters             72 Main St      Miami           FL
# 11      Brett Favre                    NaN        NaN          NaN
# 12            Apple                    NaN        NaN          NaN
#
# ...

# %%
right

# %%
dfCustomers_outer = Customers.merge(Calls , how="outer" , on="Name")

# %%
dfCustomers_outer
# Out:
#                Name                Address         City        State  \
# 0   John F. Kennedy       677 Timpany Blvd           DC           DC
# 1   John F. Kennedy       677 Timpany Blvd           DC           DC
# 2   John F. Kennedy       677 Timpany Blvd           DC           DC
# 3           Jack Ma         337 Russell St           NY           NY
# 4           Jack Ma         337 Russell St           NY           NY
# 5   Natalie Portman    295 Plymouth Street           LA           CA
# 6     Javier Bardem     1775 Washington St  Los Angeles   California
# 7     Nikolas Tesla  280 Washington Street     New York     New York
# 8   Albert Einstein          20 Soojian Dr    Princeton           NJ
# 9   Albert Einstein          20 Soojian Dr    Princeton           NJ
# 10    Romelo Lukaku  301 Massachusetts Ave     Brussels          NaN
# 11      Gareth Bale         506 State Road       London          NaN
# 12    Shahrukh Khan        742 Main Street       Mumbai  Maharashtra
# ...

# %%
append

# %%
! ls
# Out:
# Calls.xlsx
# Customers.xlsx
# Making changes on the data frame.ipynb
# Read and investigate the data.ipynb
# aggregating using GroupBy and save file.ipynb
# append.png
# join .ipynb
# join.png
# python course presention.pptx
# titanic.csv
# weather_by_cities.csv

# %%
df = pd.read_csv('weather_by_cities.csv')

# %%
df2 = pd.read_csv('weather_by_cities.csv')

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df2
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df.append(df2,sort=False)
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# ...
